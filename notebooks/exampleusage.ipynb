# %%
from emergentintensity import emergent_stokes

# Example
tau_ex = 0.1
omega_ex = 0.5
inc_ex = 45.0

I_ex, Q_ex = emergent_stokes(tau_ex, omega_ex, inc_ex)

print("\nExample (emergent_stokes):")
print(f"  I({tau_ex}, {omega_ex}, {inc_ex}deg)  = {float(I_ex):.6e}")
print(f"  Q({tau_ex}, {omega_ex}, {inc_ex}deg)  = {float(Q_ex):.6e}")
print(f"  Q/I = {float(Q_ex / I_ex) if I_ex != 0.0 else 0.0:.6e}")
# Out:
# Example (emergent_stokes):
#   I(0.1, 0.5, 45.0deg)  = 7.157505e-02
#   Q(0.1, 0.5, 45.0deg)  = 6.762812e-04
#   Q/I = 9.448561e-03
